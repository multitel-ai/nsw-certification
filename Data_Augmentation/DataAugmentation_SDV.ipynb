# %%
#!pip install deep_tabular_augmentation
import os
import numpy as np
import torch
from torch import nn
from torch import optim
from sklearn.preprocessing import StandardScaler
from functools import partial
from vpower_src.utils.auxiliary_functions import *
import matplotlib.pyplot as plt

# %%
import sdv
from sdv.metadata import SingleTableMetadata
from sdv.single_table import GaussianCopulaSynthesizer
from sdv.lite import SingleTablePreset
from sdv.single_table import CTGANSynthesizer
from sdv.single_table import CopulaGANSynthesizer

# %%
data_dir_s =  "../Data/synthetic_data"
data_dir_r =  "../Data/split_quad"
data_dir_da = "../Data/augmented_data"
data_tag="RD"

# %%
# Load data partitions and assign them to dictionary data_all
data_all = {}
#for partition in ["train", "dev_in", "dev_out"]:
#    df = load_data_and_set_index(filepath=os.path.join(data_dir_s, f"{partition}.csv"), index_column_name="index")
#    data_all[partition+"_s"] = df
for partition in ["train", "test", "val", "lourd"]:
    df = load_data_and_set_index(filepath=os.path.join(data_dir_r, f"{partition}.csv"), index_column_name="index")
    data_all[partition+"_r"] = df

if data_tag=="RD":
    data_all["train"]=data_all["train_r"]
    data_all["test"]=data_all["test_r"]
else:
    data_all["train"]=   pd.concat([data_all["train_r"], data_all["train_s"]])
    data_all["test"] = pd.concat([data_all["test_r"], data_all["test_s"]])
    

data_flight1 = {}
data_flight1["train"] = data_all["train"].loc[data_all["train"]["flight"] == 1]
data_flight1["test"] = data_all["test"].loc[data_all["test"]["flight"] == 1]
data_flight1["train"]
# Out:
#                 time_start  flight    time  wind_speed  wind_angle  \
# index
# 112    2019-04-07 10:13:00       1    0.00         1.4        37.0
# 113    2019-04-07 10:13:00       1    0.21         1.4        36.0
# 114    2019-04-07 10:13:00       1    0.31         1.4        42.0
# 115    2019-04-07 10:13:00       1    0.50         1.4        42.0
# 116    2019-04-07 10:13:00       1    0.61         1.3        41.0
# ...                    ...     ...     ...         ...         ...
# 1239   2019-04-07 10:13:00       1  169.10         1.7        92.0
# 1240   2019-04-07 10:13:00       1  169.20         1.7        90.0
# 1241   2019-04-07 10:13:00       1  169.30         1.7        92.0
# 1242   2019-04-07 10:13:00       1  169.50         1.7        93.0
# 1243   2019-04-07 10:13:00       1  169.70         1.7        94.0
#
#        battery_voltage  battery_current  position_x  position_y  position_z  \
# index
# 112          24.178350         0.389637  -79.782396   40.458047  270.407091
# 113          23.517269         6.154673  -79.782396   40.458047  270.432353
# 114          24.109488         1.025779  -79.782396   40.458047  270.433609
# 115          24.189619         0.278312  -79.782396   40.458047  270.459037
# 116          24.192123         0.389637  -79.782396   40.458047  270.460150
# ...                ...              ...         ...         ...         ...
# 1239         22.500603         5.033473  -79.782354   40.458037  268.150388
# 1240         22.493092         5.089135  -79.782354   40.458037  268.170896
# 1241         22.498098         5.025521  -79.782354   40.458037  268.153808
# 1242         22.506863         5.176605  -79.782354   40.458037  268.164205
# 1243         22.797338         0.143132  -79.782354   40.458037  268.178613
#
#        ...  angular_z  linear_acceleration_x  linear_acceleration_y  \
# index  ...
# 112    ...  -0.000479               0.033248              -0.114812
# 113    ...   0.011397               0.042173              -0.108319
# 114    ...   0.017794               0.005411              -0.188141
# 115    ...  -0.005043               0.034055              -0.114786
# 116    ...  -0.012929               0.008335              -0.094107
# ...    ...        ...                    ...                    ...
# 1239   ...   0.022862               0.264301               0.581728
# 1240   ...  -0.011390               0.207800               0.540354
# 1241   ...  -0.000938               0.246509               0.592650
# 1242   ...  -0.012062               0.161688               0.608997
# 1243   ...   0.018540               0.266580               0.629168
#
#        linear_acceleration_z  speed  payload  altitude  route       power  \
# index
# 112                -9.824341      4        0        25     R5    9.420778
# 113                -9.837841      4        0        25     R5  144.741104
# 114                -9.812851      4        0        25     R5   24.731003
# 115                -9.808225      4        0        25     R5    6.732263
# 116                -9.812603      4        0        25     R5    9.426145
# ...                      ...    ...      ...       ...    ...         ...
# 1239               -9.760308      4        0        25     R5  113.256177
# 1240               -9.742634      4        0        25     R5  114.470383
# 1241               -9.784649      4        0        25     R5  113.064672
# 1242               -9.730863      4        0        25     R5  116.509132
# 1243               -9.792398      4        0        25     R5    3.263027
#
#        power_smoothed
# index
# 112          9.420778
# 113        144.741104
# 114         24.731003
# 115          6.732263
# 116          9.426145
# ...               ...
# 1239       113.256177
# 1240       114.470383
# 1241       113.064672
# 1242       116.509132
# 1243         3.263027
#
# [815 rows x 29 columns]

# %%
real_data=data_all["train"]
len(real_data)
# Out:
# 139006

# %%
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=real_data)
print('Auto detected data:\n')
metadata
# Out:
# Auto detected data:
# {
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1",
#     "columns": {
#         "time_start": {
#             "sdtype": "categorical"
#         },
#         "flight": {
#             "sdtype": "numerical"
#         },
#         "time": {
#             "sdtype": "numerical"
#         },
#         "wind_speed": {
#             "sdtype": "numerical"
#         },
#         "wind_angle": {
#             "sdtype": "numerical"
#         },
#         "battery_voltage": {
#             "sdtype": "numerical"
#         },
#         "battery_current": {
#             "sdtype": "numerical"
#         },
#         "position_x": {
#             "sdtype": "numerical"
#         },
#         "position_y": {
#             "sdtype": "numerical"
#         },
#         "position_z": {
#             "sdtype": "numerical"
#         },
#         "orientation_x": {
#             "sdtype": "numerical"
#         },
#         "orientation_y": {
#             "sdtype": "numerical"
#         },
#         "orientation_z": {
#             "sdtype": "numerical"
#         },
#         "orientation_w": {
#             "sdtype": "numerical"
#         },
#         "velocity_x": {
#             "sdtype": "numerical"
#         },
#         "velocity_y": {
#             "sdtype": "numerical"
#         },
#         "velocity_z": {
#             "sdtype": "numerical"
#         },
#         "angular_x": {
#             "sdtype": "numerical"
#         },
#         "angular_y": {
#             "sdtype": "numerical"
#         },
#         "angular_z": {
#             "sdtype": "numerical"
#         },
#         "linear_acceleration_x": {
#             "sdtype": "numerical"
#         },
#         "linear_acceleration_y": {
#             "sdtype": "numerical"
#         },
#         "linear_acceleration_z": {
#             "sdtype": "numerical"
#         },
#         "speed": {
#             "sdtype": "numerical"
#         },
#         "payload": {
#             "sdtype": "numerical"
#         },
#         "altitude": {
#             "sdtype": "categorical"
#         },
#         "route": {
#             "sdtype": "categorical"
#         },
#         "power": {
#             "sdtype": "numerical"
#         },
#         "power_smoothed": {
#             "sdtype": "numerical"
#         }
#     }
# }

# %%
#GaussianCopulaSynthesizer

# Step 1: Create the synthesizer
synthesizer = GaussianCopulaSynthesizer(metadata)

# Step 2: Train the synthesizer
synthesizer.fit(real_data)
synthesizer.save(filepath='my_GaussianCopulaSynthesizer.pkl')
# Out:
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'time'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'wind_speed'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'battery_voltage'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'battery_current'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'position_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'position_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_w'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'power'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'power_smoothed'. Data will not be rounded.
#   warnings.warn(

# %%
#CopulaGANSynthesizer

# Step 1: Create the synthesizer
synthesizer_GAN = CopulaGANSynthesizer(metadata)

# Step 2: Train the synthesizer
synthesizer_GAN.fit(real_data)
synthesizer_GAN.save(filepath='my_CopulaGANSynthesizer.pkl')
# Out:
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'time'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'wind_speed'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'battery_voltage'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'battery_current'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'position_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'position_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_w'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'power'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'power_smoothed'. Data will not be rounded.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_173010/211395547.py in <module>
#       5
#       6 # Step 2: Train the synthesizer
# ----> 7 synthesizer_GAN.fit(real_data)
#       8 synthesizer_GAN.save(filepath='my_CopulaGANSynthesizer.pkl')
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/base.py in fit(self, data)
#     376         self._random_state_set = False
#     377         processed_data = self._preprocess(data)
# --> 378         self.fit_processed_data(processed_data)
#     379
#     380     def save(self, filepath):
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/base.py in fit_processed_data(self, processed_data)
#     359         """
#     360         if not processed_data.empty:
# --> 361             self._fit(processed_data)
#     362
#     363         self._fitted = True
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/copulagan.py in _fit(self, processed_data)
#     193         self._gaussian_normalizer_hyper_transformer = rdt.HyperTransformer()
#     194         self._gaussian_normalizer_hyper_transformer.set_config(gaussian_normalizer_config)
# --> 195         processed_data = self._gaussian_normalizer_hyper_transformer.fit_transform(processed_data)
#     196
#     197         super()._fit(processed_data)
#
# ~/.local/lib/python3.8/site-packages/rdt/hyper_transformer.py in fit_transform(self, data)
#     676                 Transformed data.
#     677         """
# --> 678         self.fit(data)
#     679         return self.transform(data)
#     680
#
# ~/.local/lib/python3.8/site-packages/rdt/hyper_transformer.py in fit(self, data)
#     605         self._input_columns = list(data.columns)
#     606         for field in self._input_columns:
# --> 607             data = self._fit_field_transformer(data, field, self.field_transformers[field])
#     608
#     609         self._validate_all_fields_fitted()
#
# ~/.local/lib/python3.8/site-packages/rdt/hyper_transformer.py in _fit_field_transformer(self, data, field, transformer)
#     542
#     543         else:
# --> 544             transformer.fit(data, field)
#     545             self._transformers_sequence.append(transformer)
#     546             data = transformer.transform(data)
#
# ~/.local/lib/python3.8/site-packages/rdt/transformers/base.py in wrapper(self, *args, **kwargs)
#      53         method_name = function.__name__
#      54         with set_random_states(self.random_states, method_name, self.set_random_state):
# ---> 55             return function(self, *args, **kwargs)
#      56
#      57     return wrapper
#
# ~/.local/lib/python3.8/site-packages/rdt/transformers/base.py in fit(self, data, column)
#     388         self._set_seed(data)
#     389         columns_data = self._get_columns_data(data, self.columns)
# --> 390         self._fit(columns_data)
#     391         self._build_output_columns(data)
#     392
#
# ~/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py in _fit(self, data)
#     335         with warnings.catch_warnings():
#     336             warnings.simplefilter('ignore')
# --> 337             self._univariate.fit(data)
#     338
#     339     def _copula_transform(self, data):
#
# ~/.local/lib/python3.8/site-packages/copulas/univariate/base.py in fit(self, X)
#     623             self._fit_constant(X)
#     624         else:
# --> 625             self._fit(X)
#     626
#     627         self.fitted = True
#
# ~/.local/lib/python3.8/site-packages/copulas/univariate/beta.py in _fit(self, X)
#      28         loc = np.min(X)
#      29         scale = np.max(X) - loc
# ---> 30         a, b, loc, scale = beta.fit(X, loc=loc, scale=scale)
#      31         self._params = {
#      32             'loc': loc,
#
# /opt/conda/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py in wrapper(self, *args, **kwds)
#      64             return super(type(self), self).fit(*args, **kwds)
#      65         else:
# ---> 66             return fun(self, *args, **kwds)
#      67     return wrapper
#      68
#
# /opt/conda/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py in fit(self, data, *args, **kwds)
#     730         if floc is None or fscale is None:
#     731             # do general fit
# --> 732             return super().fit(data, *args, **kwds)
#     733
#     734         # We already got these from kwds, so just pop them.
#
# /opt/conda/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py in fit(self, data, *args, **kwds)
#    2677         # especially when the user fixes parameters. Minimizing the sum
#    2678         # of squares of the error generalizes to these cases.
# -> 2679         vals = optimizer(func, x0, args=(ravel(data),), disp=0)
#    2680         obj = func(vals, data)
#    2681
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/_optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     693             'initial_simplex': initial_simplex}
#     694
# --> 695     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     696     if full_output:
#     697         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/_optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     868             if bounds is not None:
#     869                 xr = np.clip(xr, lower_bound, upper_bound)
# --> 870             fxr = func(xr)
#     871             doshrink = 0
#     872
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/_optimize.py in function_wrapper(x, *wrapper_args)
#     567         ncalls[0] += 1
#     568         # A copy of x is sent to the user function (gh13740)
# --> 569         fx = function(np.copy(x), *(wrapper_args + args))
#     570         # Ideally, we'd like to a have a true scalar returned from f(x). For
#     571         # backwards-compatibility, also allow np.array([1.3]),
#
# /opt/conda/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py in _penalized_nnlf(self, theta, x)
#    1636         x = asarray((x-loc) / scale)
#    1637         n_log_scale = len(x) * log(scale)
# -> 1638         return self._nlff_and_penalty(x, args, self._logpxf) + n_log_scale
#    1639
#    1640     def _penalized_nlpsf(self, theta, x):
#
# /opt/conda/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py in _nlff_and_penalty(self, x, args, log_fitfun)
#    1618         if n_bad > 0:
#    1619             x = argsreduce(~cond0, x)[0]
# -> 1620         logff = log_fitfun(x, *args)
#    1621         finite_logff = np.isfinite(logff)
#    1622         n_bad += np.sum(~finite_logff, axis=0)
#
# /opt/conda/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py in _logpxf(self, x, *args)
#    2054         # the distinction doesn't matter. This lets us use `_logpxf` for both
#    2055         # discrete and continuous distributions.
# -> 2056         return self._logpdf(x, *args)
#    2057
#    2058     def _cdf_single(self, x, *args):
#
# /opt/conda/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py in _logpdf(self, x, a, b)
#     671
#     672     def _logpdf(self, x, a, b):
# --> 673         lPx = sc.xlog1py(b - 1.0, -x) + sc.xlogy(a - 1.0, x)
#     674         lPx -= sc.betaln(a, b)
#     675         return lPx
#
# KeyboardInterrupt:

# %%
# Step 3: Generate synthetic data
synthetic_data = synthesizer.sample(num_rows=15000)
print(len(synthetic_data))
# Out:
# 15000

# %%
# Step 3: Generate synthetic data
synthetic_data_GAN = synthesizer_GAN.sample(num_rows=15000)
print(len(synthetic_data_GAN))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sdv/single_table/base.py in _sample_with_progress_bar(self, num_rows, max_tries_per_batch, batch_size, output_file_path, show_progress_bar)
#     731                 progress_bar.set_description('Sampling rows')
# --> 732                 sampled = self._sample_in_batches(
#     733                     num_rows=num_rows,
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/base.py in _sample_in_batches(self, num_rows, batch_size, max_tries_per_batch, conditions, transformed_conditions, float_rtol, progress_bar, output_file_path)
#     662         for step in range(math.ceil(num_rows / batch_size)):
# --> 663             sampled_rows = self._sample_batch(
#     664                 batch_size=batch_size,
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/base.py in _sample_batch(self, batch_size, max_tries, conditions, transformed_conditions, float_rtol, progress_bar, output_file_path, keep_extra_columns)
#     594             prev_num_valid = num_valid
# --> 595             sampled, num_valid = self._sample_rows(
#     596                 num_rows_to_sample,
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/base.py in _sample_rows(self, num_rows, conditions, transformed_conditions, float_rtol, previous_rows, keep_extra_columns)
#     497         """
# --> 498         if self._model and not self._random_state_set:
#     499             self._set_random_state(FIXED_RNG_SEED)
#
# AttributeError: 'CopulaGANSynthesizer' object has no attribute '_model'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_132586/3255857613.py in <module>
#       1 # Step 3: Generate synthetic data
# ----> 2 synthetic_data_GAN = synthesizer_GAN.sample(num_rows=15000)
#       3 print(len(synthetic_data_GAN))
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/base.py in sample(self, num_rows, max_tries_per_batch, batch_size, output_file_path)
#     769         show_progress_bar = has_constraints or has_batches
#     770
# --> 771         return self._sample_with_progress_bar(
#     772             num_rows,
#     773             max_tries_per_batch,
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/base.py in _sample_with_progress_bar(self, num_rows, max_tries_per_batch, batch_size, output_file_path, show_progress_bar)
#     739
#     740         except (Exception, KeyboardInterrupt) as error:
# --> 741             handle_sampling_error(output_file_path == TMP_FILE_NAME, output_file_path, error)
#     742
#     743         else:
#
# ~/.local/lib/python3.8/site-packages/sdv/single_table/utils.py in handle_sampling_error(is_tmp_file, output_file_path, sampling_error)
#      95
#      96     if error_msg:
# ---> 97         raise type(sampling_error)(error_msg + '\n' + str(sampling_error))
#      98
#      99     raise sampling_error
#
# AttributeError: Error: Sampling terminated. Partial results are stored in a temporary file: .sample.csv.temp. This file will be overridden the next time you sample. Please rename the file if you wish to save these results.
# 'CopulaGANSynthesizer' object has no attribute '_model'

# %%
feature_under_study = "power_smoothed"

plt.figure(figsize=(6, 6))
plt.scatter(real_data["time"], real_data['power_smoothed'] / 1e3,
            c=real_data[feature_under_study],
            s=4, label="REAL_ALL")
plt.legend(loc="upper left")
plt.xlabel("Time")
plt.ylabel("Power")
#plt.xlim(4, 25)
#plt.ylim(-2, 45)
plt.grid()

cbar = plt.colorbar()
cbar.set_label(feature_under_study, rotation=90)
plt.clim(-15, 50)

plt.show()
plt.close()

############################################################
feature_under_study = "power_smoothed"

plt.figure(figsize=(6, 6))
plt.scatter(synthetic_data["time"],synthetic_data['power_smoothed'] / 1e3,
            c=synthetic_data[feature_under_study],
            s=4, label="FAKE_Gaussian_ALL")
plt.legend(loc="upper left")
plt.xlabel("Time")
plt.ylabel("Power")
#plt.xlim(4, 25)
#plt.ylim(-2, 45)
plt.grid()

cbar = plt.colorbar()
cbar.set_label(feature_under_study, rotation=90)
plt.clim(-15, 50)

plt.show()
plt.close()

############################################################
feature_under_study = "power_smoothed"

plt.figure(figsize=(6, 6))
plt.scatter(synthetic_data_GAN["time"],synthetic_data_GAN['power_smoothed'] / 1e3,
            c=synthetic_data_GAN[feature_under_study],
            s=4, label="FAKE_GAN_ALL")
plt.legend(loc="upper left")
plt.xlabel("Time")
plt.ylabel("Power")
#plt.xlim(4, 25)
#plt.ylim(-2, 45)
plt.grid()

cbar = plt.colorbar()
cbar.set_label(feature_under_study, rotation=90)
plt.clim(-15, 50)

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_173010/1220065837.py in <module>
#      44
#      45 plt.figure(figsize=(6, 6))
# ---> 46 plt.scatter(synthetic_data_GAN["time"],synthetic_data_GAN['power_smoothed'] / 1e3,
#      47             c=synthetic_data_GAN[feature_under_study],
#      48             s=4, label="FAKE_GAN_ALL")
#
# NameError: name 'synthetic_data_GAN' is not defined

# %% [markdown]
# # Data Augmentation only on 1 flight

# %%
real_data_flight1 = data_flight1["train"]
print("Real_Data Length", len(real_data_flight1))

metadata_flight1 = SingleTableMetadata()
metadata_flight1.detect_from_dataframe(data=real_data_flight1)
print("Auto detected data:\n", metadata_flight1)
# Out:
# Real_Data Length 815
# Auto detected data:
#  {
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1",
#     "columns": {
#         "time_start": {
#             "sdtype": "categorical"
#         },
#         "flight": {
#             "sdtype": "numerical"
#         },
#         "time": {
#             "sdtype": "numerical"
#         },
#         "wind_speed": {
#             "sdtype": "numerical"
#         },
#         "wind_angle": {
#             "sdtype": "numerical"
#         },
#         "battery_voltage": {
#             "sdtype": "numerical"
#         },
#         "battery_current": {
#             "sdtype": "numerical"
#         },
#         "position_x": {
#             "sdtype": "numerical"
#         },
#         "position_y": {
#             "sdtype": "numerical"
#         },
#         "position_z": {
#             "sdtype": "numerical"
#         },
#         "orientation_x": {
#             "sdtype": "numerical"
#         },
#         "orientation_y": {
#             "sdtype": "numerical"
#         },
#         "orientation_z": {
#             "sdtype": "numerical"
#         },
#         "orientation_w": {
#             "sdtype": "numerical"
#         },
#         "velocity_x": {
#             "sdtype": "numerical"
#         },
#         "velocity_y": {
#             "sdtype": "numerical"
#         },
#         "velocity_z": {
#             "sdtype": "numerical"
#         },
#         "angular_x": {
#             "sdtype": "numerical"
#         },
#         "angular_y": {
#             "sdtype": "numerical"
#         },
#         "angular_z": {
#             "sdtype": "numerical"
#         },
#         "linear_acceleration_x": {
#             "sdtype": "numerical"
#         },
#         "linear_acceleration_y": {
#             "sdtype": "numerical"
#         },
#         "linear_acceleration_z": {
#             "sdtype": "numerical"
#         },
#         "speed": {
#             "sdtype": "numerical"
#         },
#         "payload": {
#             "sdtype": "numerical"
#         },
#         "altitude": {
#             "sdtype": "categorical"
#         },
#         "route": {
#             "sdtype": "categorical"
#         },
#         "power": {
#             "sdtype": "numerical"
#         },
#         "power_smoothed": {
#             "sdtype": "numerical"
#         }
#     }
# }

# %%
#GaussianCopulaSynthesizer
# Step 1: Create the synthesizer
synthesizer_Gaussian_flight1 = GaussianCopulaSynthesizer(metadata_flight1)

# Step 2: Train the synthesizer
synthesizer_Gaussian_flight1.fit(real_data_flight1)
synthesizer_Gaussian_flight1.save(filepath='my_GaussianCopulaSynthesizer_flight1.pkl')
# Out:
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'time'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'wind_speed'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'battery_voltage'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'battery_current'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'position_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_w'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'power'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'power_smoothed'. Data will not be rounded.
#   warnings.warn(

# %%
# Step 3: Generate synthetic data - Gaussian
synthetic_data_Gaussian_flight1 = synthesizer_Gaussian_flight1.sample(num_rows=815)
print(len(synthetic_data_Gaussian_flight1))
# Out:
# 815

# %%
#CopulaGANSynthesizer
# Step 1: Create the synthesizer
synthesizer_GAN_flight1 = CopulaGANSynthesizer(metadata_flight1)

# Step 2: Train the synthesizer
synthesizer_GAN_flight1.fit(real_data_flight1)
synthesizer_GAN_flight1.save(filepath='my_CopulaGANSynthesizer_flight1.pkl')
# Out:
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'time'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'wind_speed'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'battery_voltage'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'battery_current'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'position_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'orientation_w'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'velocity_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'angular_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_x'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_y'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'linear_acceleration_z'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'power'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/numerical.py:112: UserWarning: No rounding scheme detected for column 'power_smoothed'. Data will not be rounded.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /home/user/.local/lib/python3.8/site-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(

# %%
# Step 3: Generate synthetic data - GAN
synthetic_data_GAN_flight1 = synthesizer_GAN_flight1.sample(num_rows=15000)
print(len(synthetic_data_GAN_flight1))
# Out:
# 15000

# %%
# Step 4: Display Real data
print(len(real_data_flight1))
feature_under_study = "power_smoothed"

plt.figure(figsize=(6, 6))
plt.scatter(real_data_flight1["time"],real_data_flight1['power_smoothed'] / 1e3,
            c=real_data_flight1[feature_under_study],
            s=4, label="REAL_Flight_1")
plt.legend(loc="upper left")
plt.xlabel("Time")
plt.ylabel("Power")
#plt.xlim(4, 25)
#plt.ylim(-2, 45)
plt.grid()

cbar = plt.colorbar()
cbar.set_label(feature_under_study, rotation=90)
plt.clim(-15, 50)

plt.show()
plt.close()
# Out:
# 815

# %%
# Step 4: Display Synthetic data - Gaussian
feature_under_study = "power_smoothed"

plt.figure(figsize=(6, 6))
plt.scatter(synthetic_data_Gaussian_flight1["time"],synthetic_data_Gaussian_flight1['power_smoothed'] / 1e3,
            c=synthetic_data_Gaussian_flight1[feature_under_study],
            s=4, label="FAKE_Gaussian_Flight_1")
plt.legend(loc="upper left")
plt.xlabel("Time")
plt.ylabel("Power")
#plt.xlim(4, 25)
#plt.ylim(-2, 45)
plt.grid()

cbar = plt.colorbar()
cbar.set_label(feature_under_study, rotation=90)
plt.clim(-15, 50)

plt.show()
plt.close()

# %%
# Step 4: Display Synthetic data - GAN
feature_under_study = "power_smoothed"

plt.figure(figsize=(6, 6))
plt.scatter(synthetic_data_GAN_flight1["time"],synthetic_data_GAN_flight1['power_smoothed'] / 1e3,
            c=synthetic_data_GAN_flight1[feature_under_study],
            s=4, label="FAKE_GAN_Flight_1")
plt.legend(loc="upper left")
plt.xlabel("Time")
plt.ylabel("Power")
#plt.xlim(4, 25)
#plt.ylim(-2, 45)
plt.grid()

cbar = plt.colorbar()
cbar.set_label(feature_under_study, rotation=90)
plt.clim(-15, 50)

plt.show()
plt.close()

# %% [markdown]
# # Evaluating real / synthetic data

# %%
from sdv.evaluation.single_table import evaluate_quality

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata
)
