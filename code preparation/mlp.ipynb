# %%
# from sklearnex import patch_sklearn
# patch_sklearn()

import os

from src.utils import read_complete ,read_split_csv
from src.mlp.mlp import *
from src.mlp.mlp_plot import *
from src.mlp.scaling_uncertainty import *

# %%
import json
import pandas as pd
import torch
print("Torch Version", torch.__version__)

import sys
sys.path.append("..")


from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

from scipy.stats import circmean, circstd
# Out:
# Torch Version 1.11.0

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# if not, in shell :
#
# sudo rmmod nvidia_uvm && sudo modprobe nvidia_uvm

# %% [markdown]
# # Load data
# (quadricoptere dataset)

# %%
datasets = read_split_csv("/App/Data/split_quad/")#, engine="python")
datasets["val"]
# Out:
# val.csv
# train.csv
# test.csv
# lourd.csv
#                  time_start  flight    time  wind_speed  wind_angle  \
# index
# 109923  2019-07-03 03:10:00     150   35.50         2.8       238.0
# 91658   2019-06-29 12:40:00     136   78.60         9.4         4.0
# 200354  2019-07-24 16:28:00     229   62.60        10.5       204.0
# 122937  2019-07-03 16:35:00     162    3.10         0.9       265.0
# 164684  2019-07-15 08:05:00     195  112.60         2.2       128.0
# ...                     ...     ...     ...         ...         ...
# 119371  2019-07-03 16:10:00     158    4.20         1.0        70.0
# 228319  2019-08-05 18:00:00     252   53.61         2.8       212.0
# 255344  2019-10-24 09:45:00     277   72.01         9.0        14.0
# 29521   2019-06-11 10:30:00      82   33.40         8.7       349.0
# 135370  2019-07-09 12:09:00     172   76.60         5.8       200.0
#
#         battery_voltage  battery_current  position_x  position_y  position_z  \
# index
# 109923        22.759777        23.505444  -79.782777   40.458953  365.169441
# 91658         21.084534        26.065914  -79.782571   40.458586  290.375622
# 200354        22.172565        18.448116  -79.782210   40.458218  315.845911
# 122937        21.716820        24.189297  -79.782738   40.458992  276.467557
# 164684        23.306925        17.772215  -79.782766   40.459063  367.520864
# ...                 ...              ...         ...         ...         ...
# 119371        22.375399        21.795813  -79.782763   40.458980  270.231115
# 228319        21.711811        26.304468  -79.781380   40.459499  345.136230
# 255344        21.670494        21.390272  -79.782571   40.458526  293.235121
# 29521         21.243544        27.560848  -79.782744   40.458968  338.757659
# 135370        23.647482        19.943048  -79.781546   40.459243  368.284307
#
#         ...  angular_z  linear_acceleration_x  linear_acceleration_y  \
# index   ...
# 109923  ...  -0.076906               0.335496              -0.143232
# 91658   ...  -0.082310              -1.529684               0.423300
# 200354  ...   0.015051              -1.633767               0.061935
# 122937  ...  -0.054514               0.133585              -0.133318
# 164684  ...   0.018428               0.267958              -0.178819
# ...     ...        ...                    ...                    ...
# 119371  ...   0.012899               0.072653               0.035458
# 228319  ...  -0.000584              -0.393476               0.177744
# 255344  ...  -0.107946              -0.764824               0.548552
# 29521   ...  -0.112906              -0.559980               1.688861
# 135370  ...   0.096786              -0.331869              -0.189710
#
#         linear_acceleration_z  speed  payload  altitude  route       power  \
# index
# 109923              -9.869870     12        0       100     R1  534.978656
# 91658               -9.976319      8      250        25     R1  549.587645
# 200354              -9.457129     10        0        50     R1  409.042066
# 122937             -10.589297      8      500        75     R1  525.314597
# 164684              -8.603159      8      250       100     R1  414.215676
# ...                       ...    ...      ...       ...    ...         ...
# 119371              -9.965531     12      250        75     R1  487.689996
# 228319              -9.913366     12      500        75     R1  571.117643
# 255344              -9.283231     10      500        25     R1  463.537766
# 29521              -10.585027      8        0        75     R1  585.490082
# 135370             -10.470071      6        0       100     R1  471.602878
#
#         power_smoothed
# index
# 109923      537.998819
# 91658       526.000169
# 200354      432.243997
# 122937      536.179872
# 164684      420.793236
# ...                ...
# 119371      544.146733
# 228319      586.617433
# 255344      460.171522
# 29521       524.172464
# 135370      475.375547
#
# [15446 rows x 29 columns]

# %%
# remove columns 
cols_ignored = ["time_start","battery_voltage","battery_current", "altitude","speed","route", "position_x", "position_y", "flight"]
cols_redundent = ["linear_acceleration_x", "velocity_y", "power"]
target = ["power_smoothed"]

datasets_cleaned = dict()
for k in datasets.keys():
    datasets_cleaned[k] = datasets[k].drop(columns = cols_ignored + cols_redundent) # + target)

datasets_cleaned["val"]
# Out:
#           time  wind_speed  wind_angle  position_z  orientation_x  \
# index
# 109923   35.50         2.8       238.0  365.169441       0.019652
# 91658    78.60         9.4         4.0  290.375622      -0.065850
# 200354   62.60        10.5       204.0  315.845911      -0.020135
# 122937    3.10         0.9       265.0  276.467557      -0.029125
# 164684  112.60         2.2       128.0  367.520864       0.002847
# ...        ...         ...         ...         ...            ...
# 119371    4.20         1.0        70.0  270.231115      -0.001946
# 228319   53.61         2.8       212.0  345.136230      -0.028327
# 255344   72.01         9.0        14.0  293.235121      -0.013434
# 29521    33.40         8.7       349.0  338.757659      -0.190561
# 135370   76.60         5.8       200.0  368.284307      -0.022999
#
#         orientation_y  orientation_z  orientation_w  velocity_x  velocity_z  \
# index
# 109923      -0.009543      -0.892996       0.449534   -0.079833    3.000340
# 91658       -0.020889       0.102929       0.992287   -0.505729    0.908372
# 200354      -0.081124       0.972382       0.217915    0.079185    1.620667
# 122937      -0.007355      -0.769531       0.637903   -0.045260    0.282797
# 164684       0.011134       0.129321       0.991536    0.140437   -1.149955
# ...               ...            ...            ...         ...         ...
# 119371      -0.004951      -0.731368       0.681962    0.014317    0.171766
# 228319      -0.122869       0.967072       0.221073    0.018804    1.762058
# 255344      -0.028738       0.109309       0.993502   -0.773985   -0.051941
# 29521        0.046814      -0.624123       0.756284   -0.627038    0.047944
# 135370      -0.034945       0.974178       0.221873   -0.062418    0.144803
#
#         angular_x  angular_y  angular_z  linear_acceleration_y  \
# index
# 109923   0.006295   0.028133  -0.076906              -0.143232
# 91658    0.071907   0.034870  -0.082310               0.423300
# 200354  -0.015960   0.032285   0.015051               0.061935
# 122937   0.178007   0.083491  -0.054514              -0.133318
# 164684  -0.005068   0.014159   0.018428              -0.178819
# ...           ...        ...        ...                    ...
# 119371  -0.027388   0.043483   0.012899               0.035458
# 228319  -0.044206   0.016506  -0.000584               0.177744
# 255344   0.131445  -0.257779  -0.107946               0.548552
# 29521    0.011048   0.149999  -0.112906               1.688861
# 135370  -0.011851  -0.076299   0.096786              -0.189710
#
#         linear_acceleration_z  payload  power_smoothed
# index
# 109923              -9.869870        0      537.998819
# 91658               -9.976319      250      526.000169
# 200354              -9.457129        0      432.243997
# 122937             -10.589297      500      536.179872
# 164684              -8.603159      250      420.793236
# ...                       ...      ...             ...
# 119371              -9.965531      250      544.146733
# 228319              -9.913366      500      586.617433
# 255344              -9.283231      500      460.171522
# 29521              -10.585027        0      524.172464
# 135370             -10.470071        0      475.375547
#
# [15446 rows x 17 columns]

# %% [markdown]
# ## Data scaling
#
# Data scaling description:
# * For the time feature `time` we perform a `zeromax` scaling using the maximum time over training set.
# * The flight number is not scaled
# * The rest input features and the target are `standardized` (Z-scaling).

# %%
target = "power_smoothed"
input_features = list(datasets_cleaned["train"].columns)
input_features.remove(target)
print(input_features)

# folder to store models and stats
model_dir = "/App/code preparation/baselines"
# Out:
# ['time', 'wind_speed', 'wind_angle', 'position_z', 'orientation_x', 'orientation_y', 'orientation_z', 'orientation_w', 'velocity_x', 'velocity_z', 'angular_x', 'angular_y', 'angular_z', 'linear_acceleration_y', 'linear_acceleration_z', 'payload']

# %%
train_data = datasets_cleaned["train"]

# store stats computed on training data so we can use them for inference
means, stds = store_stats(train_data, model_dir)
# time max for max scaling
time_max = train_data.time.max()

# %%
data_all_norm = {}
for k in datasets_cleaned.keys():
    data_all_norm[k] = data_normalization(data=datasets_cleaned[k], means=means, stds=stds, time_max=time_max)

# %%
train_norm = data_normalization(data=train_data, means=means, stds=stds, time_max=time_max)

dev_in_data = datasets_cleaned["test"]
dev_in_norm = data_normalization(data=dev_in_data, means=means, stds=stds, time_max=time_max)

train_norm
# Out:
#         angular_x  angular_y  angular_z  linear_acceleration_y  \
# index
# 73245    0.655824   0.184456  -0.171442               0.333621
# 16830   -0.035753   0.355712  -0.733666               1.984459
# 256306   1.364210  -0.172487   0.223178              -0.261906
# 92785   -0.362237   0.290305  -0.719936               3.129304
# 58106    0.224665  -0.375548  -0.120677              -0.895484
# ...           ...        ...        ...                    ...
# 86435   -0.041423  -0.038187   0.478742               1.055518
# 257631  -0.409300   0.265893  -0.422280               0.583397
# 101588  -1.069225   0.185275  -0.708103               0.499390
# 171310   0.404904   0.302077  -0.193718              -0.008841
# 139363   1.165174   0.797096  -0.595710               1.126991
#
#         linear_acceleration_z  orientation_w  orientation_x  orientation_y  \
# index
# 73245               -4.967999      -0.880669       0.454052       0.229560
# 16830               -0.154424       1.217911      -0.305529      -0.346488
# 256306               0.527392      -1.034703      -0.635105      -2.314157
# 92785                1.658736       1.174823      -2.023530      -1.110646
# 58106                1.199466      -1.654210       0.603554       0.395324
# ...                       ...            ...            ...            ...
# 86435               -0.185559       1.156269      -2.241585      -0.771591
# 257631               0.415668       1.227503       0.757584       0.283303
# 101588               0.429168       1.196028      -1.189949      -0.679506
# 171310              -0.219773       1.213535      -0.133451       0.272776
# 139363              -0.537798       0.755536      -0.905972       0.548088
#
#         orientation_z   payload  position_z  power_smoothed  velocity_x  \
# index
# 73245        1.352152  0.007379   -1.346699        1.937011    0.561537
# 16830        0.159482  0.007379   -0.715804        0.138210   -1.024095
# 256306       1.357951  1.221184    0.882617        1.563948   -0.931588
# 92785        0.226805  0.007379    1.767828        0.175483    0.576308
# 58106       -1.319698 -1.206427   -1.175607        0.635170   -0.609908
# ...               ...       ...         ...             ...         ...
# 86435        0.277924  1.221184    0.130878        0.323648   -0.093198
# 257631       0.105737 -1.206427   -0.884261       -0.529817    0.318283
# 101588       0.213055  1.221184    0.163840       -0.452858   -0.443822
# 171310       0.191662  1.221184   -0.584720        0.175695   -0.513368
# 139363      -0.689007 -1.206427    0.974445       -0.548524    0.090305
#
#         velocity_z  wind_angle  wind_speed      time
# index
# 73245     1.466609    0.990661   -0.880284  0.023432
# 16830     0.062553    2.582314    0.180172  0.442286
# 256306    2.395572    1.687598    2.153799  0.179128
# 92785     1.276056    2.883692    1.859228  0.349676
# 58106     1.146379    1.094260   -0.320598  0.029560
# ...            ...         ...         ...       ...
# 86435     1.162061    2.940201    2.006513  0.300288
# 257631   -0.728865    1.951304   -0.615170  0.350757
# 101588    0.747192   -0.290195    1.122800  0.299603
# 171310   -0.159745   -0.318450   -0.114399  0.406273
# 139363    0.269739    0.067691    0.798772  0.185652
#
# [139006 rows x 17 columns]

# %%
train_ds = VPowerDataset(data=train_norm,
                         input_features=input_features,
                         target=target)
val_ds = VPowerDataset(data=dev_in_norm,
                       input_features=input_features,
                       target=target)
                       
train_ds.norm_df.describe()
# Out:
#           angular_x     angular_y     angular_z  linear_acceleration_y  \
# count  1.390060e+05  1.390060e+05  1.390060e+05           1.390060e+05
# mean  -8.996412e-18  2.351335e-18 -9.507572e-18          -1.302691e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00           1.000000e+00
# min   -1.705390e+01 -1.827931e+01 -6.416585e+00          -8.249302e+00
# 25%   -4.833157e-01 -2.983924e-01 -3.574760e-01          -5.172347e-01
# 50%    2.342631e-03  3.006872e-03 -1.164961e-01          -3.419829e-02
# 75%    4.892355e-01  3.123176e-01  1.431176e-01           4.816354e-01
# max    1.978503e+01  1.409486e+01  7.400811e+00           9.916518e+00
#
#        linear_acceleration_z  orientation_w  orientation_x  orientation_y  \
# count           1.390060e+05   1.390060e+05   1.390060e+05   1.390060e+05
# mean           -2.743744e-13   1.230208e-15   2.074286e-16   3.354230e-16
# std             1.000000e+00   1.000000e+00   1.000000e+00   1.000000e+00
# min            -2.480568e+01  -1.755655e+00  -5.366546e+00  -5.284002e+00
# 25%            -3.308623e-01  -1.030616e+00  -3.681116e-01  -4.028865e-01
# 50%             2.269205e-02   3.325118e-01   1.520386e-01   1.106615e-01
# 75%             4.055403e-01   8.399744e-01   4.524366e-01   4.559519e-01
# max             9.470536e+00   1.231334e+00   8.115451e+00   5.816320e+00
#
#        orientation_z       payload    position_z  power_smoothed  \
# count   1.390060e+05  1.390060e+05  1.390060e+05    1.390060e+05
# mean   -1.335405e-17  8.505698e-17 -1.418450e-12    6.534155e-14
# std     1.000000e+00  1.000000e+00  1.000000e+00    1.000000e+00
# min    -1.320697e+00 -1.206427e+00 -1.725689e+00   -5.691864e+00
# 25%    -8.575250e-01 -1.206427e+00 -7.838318e-01   -4.592195e-01
# 50%     1.319233e-01  7.378572e-03 -3.517995e-02    2.676728e-02
# 75%     1.339351e+00  1.221184e+00  8.824814e-01    5.298406e-01
# max     1.412163e+00  1.221184e+00  1.947681e+00    3.859987e+00
#
#          velocity_x    velocity_z     wind_angle    wind_speed           time
# count  1.390060e+05  1.390060e+05  139006.000000  1.390060e+05  139006.000000
# mean  -7.906619e-16  4.610661e-16       1.197446 -5.784795e-16       0.279733
# std    1.000000e+00  1.000000e+00       1.000000  1.000000e+00       0.175498
# min   -1.274268e+01 -2.632926e+00      -0.431466 -1.587254e+00       0.000000
# 25%   -3.999875e-01 -7.787637e-01       0.246634 -8.213693e-01       0.133742
# 50%    1.807705e-01 -7.043224e-02       1.357966 -2.322271e-01       0.267844
# 75%    4.367156e-01  6.232662e-01       1.951304  6.514862e-01       0.406273
# max    2.442699e+01  3.252586e+00       2.949619  3.715026e+00       1.000000

# %% [markdown]
# # Model training
# Trains a certain number of models with the same architecture but there will be different initilizations. Saves them in *model_dir*.

# %%
# device = "cpu"
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("device :", device)
imin = 20
imax = 22

models_hs = train_save(imin, imax, model_dir, device, train_ds, val_ds, input_features, n_epochs=2)
# Out:
# device : cuda
# Epoch 0/2
# Average train loss: 0.8851437235579771
# Average val loss: 0.5852286674474415
# Val MSE: 0.8543466031551361
# Val MAE: 0.5707691311836243
# Saved to /App/code preparation/baselines/member_20//best_model.pth
# Epoch 1/2
# Average train loss: 0.4846805590478813
# Average val loss: 0.3918889784499219
# Val MSE: 1.1145386350782294
# Val MAE: 0.5357323477142736
# Saved to /App/code preparation/baselines/member_20//best_model.pth
# Epoch 0/2
# Average train loss: 0.815974557224442
# Average val loss: 0.557368939644412
# Val MSE: 0.9379948314867521
# Val MAE: 0.5715701391822413
# Saved to /App/code preparation/baselines/member_21//best_model.pth
# Epoch 1/2
# Average train loss: 0.4603808905710192
# Average val loss: 0.39073567249273
# Val MSE: 1.0653823472951587
# Val MAE: 0.5386917747949299
# Saved to /App/code preparation/baselines/member_21//best_model.pth
# Epoch 0/2
# Average train loss: 0.9263076677041895
# Average val loss: 0.6255925282051689
# Val MSE: 0.7309503037678567
# Val MAE: 0.5302201493790275
# Saved to /App/code preparation/baselines/member_22//best_model.pth
# Epoch 1/2
# Average train loss: 0.511496647973271
# Average val loss: 0.4755090428026099
# Val MSE: 1.3504320241903003
# Val MAE: 0.5976936268179041
# Modèle 20 :
#  Validation loss :0.3918889784499219 ; Validation MSE: 0.8543466031551361 ;                 Validation MAE: 0.5357323477142736 ; Nombre d'époques: 1
# Modèle 21 :
#  Validation loss :0.39073567249273 ; Validation MSE: 0.9379948314867521 ;                 Validation MAE: 0.5386917747949299 ; Nombre d'époques: 1
# Modèle 22 :
#  Validation loss :0.4755090428026099 ; Validation MSE: 0.7309503037678567 ;                 Validation MAE: 0.5302201493790275 ; Nombre d'époques: 0

# %%
plot_learning_curve(history=models_hs,
                    metric="loss",
                    label="NLL",
                    ylims=(0.0, 1.1)
                    )
plot_learning_curve(history=models_hs,
                    metric="mse",
                    label="MSE",
                    # ylims=(0.01, 0.2)
                    )
plot_learning_curve(history=models_hs,
                    metric="mae",
                    label="MAE",
                    # ylims=(0.1, 0.35)
                    )

# %% [markdown]
# # Model Evaluation
#
# This tutorial steps through the model evaluation process for the case of the baseline ensemble MC dropout.
#
# ## Get models and predictions

# %% [markdown]
# ### Load models
# We can load the models that we have trained before to evaluate them\
# The provided baseline is an ensemble MC dropout consisting of 10 probabilistic MC dropout neural networks that have the same structure but trained with different parameters' initialization.

# %%
loaded_models = load_models(model_dir, imin, imax, input_features)
loaded_models
# Out:
# [ProbMCdropoutDNN(
#    (linear1): Linear(in_features=16, out_features=50, bias=True)
#    (linear2): Linear(in_features=50, out_features=20, bias=True)
#    (linear3): Linear(in_features=20, out_features=2, bias=True)
#    (dropout): Dropout(p=0.005, inplace=False)
#    (softplus): Softplus(beta=1, threshold=20)
#  ),
#  ProbMCdropoutDNN(
#    (linear1): Linear(in_features=16, out_features=50, bias=True)
#    (linear2): Linear(in_features=50, out_features=20, bias=True)
#    (linear3): Linear(in_features=20, out_features=2, bias=True)
#    (dropout): Dropout(p=0.005, inplace=False)
#    (softplus): Softplus(beta=1, threshold=20)
#  ),
#  ProbMCdropoutDNN(
#    (linear1): Linear(in_features=16, out_features=50, bias=True)
#    (linear2): Linear(in_features=50, out_features=20, bias=True)
#    (linear3): Linear(in_features=20, out_features=2, bias=True)
#    (dropout): Dropout(p=0.005, inplace=False)
#    (softplus): Softplus(beta=1, threshold=20)
#  )]

# %% [markdown]
# ### Predictions et leur precision
#
# During inference, each member of the ensemble is sampled 10 times (multi_runs=10) to capture the epistemic uncertainty due to the stochasticity of the single model’s parameters.
#
# *predictions* = dictionnaire sur les datasets -> dictionnaire sur norm / denorm -> array de shape (100, nrows, 2) \
# 100 car on a 10 modèles qui donnent chacun 10 prédictions. Chaque prediction est une moyenne et une variance.

# %%
predictions = mul_predict(data_all_norm, input_features, loaded_models, means, stds, target="power_smoothed")
predictions
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 14.44it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
# 100%|██████████| 3/3 [00:00<00:00,  8.42it/s]
# 100%|██████████| 3/3 [00:00<00:00, 173.39it/s]
# {'val': {'norm': array([[[ 0.26025754,  0.06543093],
#           [-0.2141193 ,  0.13257012],
#           [-0.37341234,  0.15727748],
#           ...,
#           [-0.13715789,  0.13943942],
#           [-0.26132673,  0.11207123],
#           [-0.32063514,  0.09774199]],
#
#          [[ 0.2679872 ,  0.06868928],
#           [-0.2141193 ,  0.13257012],
#           [-0.6756079 ,  0.17217669],
#           ...,
#           [-0.16769706,  0.1692005 ],
#           [-0.29415065,  0.11884215],
#           [-0.32063514,  0.09774199]],
#
#          [[ 0.27065063,  0.06867856],
#           [-0.2141193 ,  0.13257012],
#           [-0.5764376 ,  0.17167358],
#           ...,
#           [-0.13715789,  0.13943942],
#           [-0.3013587 ,  0.11889037],
#           [-0.32063514,  0.09774199]],
#
#          ...,
#
#          [[ 0.45340002,  0.0841769 ],
#           [-0.11517363,  0.13595034],
#           [-0.55518603,  0.23518744],
#           ...,
#           [-0.1908183 ,  0.10806528],
#           [-0.15950032,  0.17391887],
#           [-0.28639475,  0.12403573]],
#
#          [[ 0.46517873,  0.08418954],
#           [-0.06226893,  0.1405819 ],
#           [-0.5154157 ,  0.24111846],
#           ...,
#           [-0.1908183 ,  0.10806528],
#           [-0.15950032,  0.17391887],
#           [-0.28639475,  0.12403573]],
#
#          [[ 0.45340002,  0.0841769 ],
#           [-0.11517363,  0.13595034],
#           [-0.58093584,  0.2253412 ],
#           ...,
#           [-0.1908183 ,  0.10806528],
#           [-0.15950032,  0.17391887],
#           [-0.28639475,  0.12403573]]], dtype=float32),
#   'denorm': array([[[ 540.3468 ,  710.80444],
#           [ 490.9036 , 1440.1664 ],
#           [ 474.3008 , 1708.5731 ],
#           ...,
#           [ 498.9251 , 1514.7906 ],
#           [ 485.98325, 1217.4781 ],
#           [ 479.80167, 1061.8135 ]],
#
#          [[ 541.15247,  746.2013 ],
#           [ 490.9036 , 1440.1664 ],
#           [ 442.80365, 1870.4297 ],
#           ...,
#           [ 495.74207, 1838.098  ],
#           [ 482.5621 , 1291.0336 ],
#           [ 479.80167, 1061.8135 ]],
#
#          [[ 541.43005,  746.08484],
#           [ 490.9036 , 1440.1664 ],
#           [ 453.13995, 1864.9642 ],
#           ...,
#           [ 498.9251 , 1514.7906 ],
#           [ 481.81082, 1291.5574 ],
#           [ 479.80167, 1061.8135 ]],
#
#          ...,
#
#          [[ 560.47766,  914.44995],
#           [ 501.21646, 1476.8872 ],
#           [ 455.35495, 2554.9426 ],
#           ...,
#           [ 493.33218, 1173.9598 ],
#           [ 496.5964 , 1889.3558 ],
#           [ 483.37048, 1347.4537 ]],
#
#          [[ 561.7053 ,  914.58734],
#           [ 506.73062, 1527.2019 ],
#           [ 459.50012, 2619.374  ],
#           ...,
#           [ 493.33218, 1173.9598 ],
#           [ 496.5964 , 1889.3558 ],
#           [ 483.37048, 1347.4537 ]],
#
#          [[ 560.47766,  914.44995],
#           [ 501.21646, 1476.8872 ],
#           [ 452.6711 , 2447.9788 ],
#           ...,
#           [ 493.33218, 1173.9598 ],
#           [ 496.5964 , 1889.3558 ],
#           [ 483.37048, 1347.4537 ]]], dtype=float32)},
#  'train': {'norm': array([[[ 2.420026  ,  0.3489587 ],
#           [ 0.0145874 ,  0.08156537],
#           [ 1.452795  ,  0.25605455],
#           ...,
#           [ 0.5103963 ,  0.13444482],
#           [ 0.39490658,  0.07212187],
#           [-0.4911819 ,  0.1101135 ]],
#
#          [[ 2.420026  ,  0.3489587 ],
#           [ 0.0145874 ,  0.08156537],
#           [ 1.452795  ,  0.25605455],
#           ...,
#           [ 0.52606493,  0.13208337],
#           [ 0.39490658,  0.07212187],
#           [-0.4911819 ,  0.1101135 ]],
#
#          [[ 2.4257061 ,  0.34553277],
#           [ 0.0145874 ,  0.08156537],
#           [ 1.4733591 ,  0.24794309],
#           ...,
#           [ 0.5103963 ,  0.13444482],
#           [ 0.39490658,  0.07212187],
#           [-0.48301584,  0.10276816]],
#
#          ...,
#
#          [[ 2.7820275 ,  0.2403302 ],
#           [ 0.06876705,  0.11239603],
#           [ 1.5432013 ,  0.32248068],
#           ...,
#           [ 0.5510953 ,  0.13923575],
#           [ 0.36706233,  0.09260549],
#           [-0.4034086 ,  0.14826052]],
#
#          [[ 2.7820275 ,  0.2403302 ],
#           [ 0.06876705,  0.11239603],
#           [ 1.5567605 ,  0.3175458 ],
#           ...,
#           [ 0.5510953 ,  0.13923575],
#           [ 0.45250446,  0.07285395],
#           [-0.4034086 ,  0.14826052]],
#
#          [[ 2.7820275 ,  0.2403302 ],
#           [ 0.06876705,  0.11239603],
#           [ 1.5567605 ,  0.3175458 ],
#           ...,
#           [ 0.5510953 ,  0.13923575],
#           [ 0.44830897,  0.067169  ],
#           [-0.4034086 ,  0.14826052]]], dtype=float32),
#   'denorm': array([[[ 765.4547 , 3790.889  ],
#           [ 514.74115,  886.07983],
#           [ 664.6424 , 2781.631  ],
#           ...,
#           [ 566.4182 , 1460.5321 ],
#           [ 554.381  ,  783.491  ],
#           [ 462.02597, 1196.2104 ]],
#
#          [[ 765.4547 , 3790.889  ],
#           [ 514.74115,  886.07983],
#           [ 664.6424 , 2781.631  ],
#           ...,
#           [ 568.05133, 1434.8787 ],
#           [ 554.381  ,  783.491  ],
#           [ 462.02597, 1196.2104 ]],
#
#          [[ 766.04675, 3753.6716 ],
#           [ 514.74115,  886.07983],
#           [ 666.78577, 2693.5127 ],
#           ...,
#           [ 566.4182 , 1460.5321 ],
#           [ 554.381  ,  783.491  ],
#           [ 462.87708, 1116.4149 ]],
#
#          ...,
#
#          [[ 803.1853 , 2610.8108 ],
#           [ 520.3882 , 1221.0066 ],
#           [ 674.06525, 3503.2468 ],
#           ...,
#           [ 570.6602 , 1512.578  ],
#           [ 551.4789 , 1006.0134 ],
#           [ 471.17438, 1610.618  ]],
#
#          [[ 803.1853 , 2610.8108 ],
#           [ 520.3882 , 1221.0066 ],
#           [ 675.47845, 3449.6372 ],
#           ...,
#           [ 570.6602 , 1512.578  ],
#           [ 560.3843 ,  791.4439 ],
#           [ 471.17438, 1610.618  ]],
#
#          [[ 803.1853 , 2610.8108 ],
#           [ 520.3882 , 1221.0066 ],
#           [ 675.47845, 3449.6372 ],
#           ...,
#           [ 570.6602 , 1512.578  ],
#           [ 559.947  ,  729.6858 ],
#           [ 471.17438, 1610.618  ]]], dtype=float32)},
#  'test': {'norm': array([[[-0.65857005,  0.11183759],
#           [-0.20531815,  0.07692197],
#           [ 0.46034795,  0.05420268],
#           ...,
#           [ 0.43045217,  0.27734116],
#           [-0.01121201,  0.10240606],
#           [-0.20257694,  0.19319397]],
#
#          [[-0.65828973,  0.11174323],
#           [-0.22826563,  0.10773014],
#           [ 0.46034795,  0.05420268],
#           ...,
#           [ 0.4213373 ,  0.27747193],
#           [-0.01121201,  0.10240606],
#           [-0.0423433 ,  0.19580775]],
#
#          [[-0.65841407,  0.11118009],
#           [-0.20531815,  0.07692197],
#           [ 0.46034795,  0.05420268],
#           ...,
#           [ 0.43266124,  0.2769237 ],
#           [-0.01121201,  0.10240606],
#           [-0.03298482,  0.19236946]],
#
#          ...,
#
#          [[-0.5670761 ,  0.09061327],
#           [-0.5937072 ,  0.51920307],
#           [ 0.5202733 ,  0.06640176],
#           ...,
#           [ 0.6891873 ,  0.37991017],
#           [ 0.04078049,  0.0851227 ],
#           [ 0.15809637,  0.16280222]],
#
#          [[-0.5670761 ,  0.09061327],
#           [-0.5937072 ,  0.51920307],
#           [ 0.5202733 ,  0.06640176],
#           ...,
#           [ 0.6891873 ,  0.37991017],
#           [ 0.04078049,  0.0851227 ],
#           [ 0.14305201,  0.16335373]],
#
#          [[-0.422881  ,  0.12775242],
#           [-0.5937072 ,  0.51920307],
#           [ 0.5202733 ,  0.06640176],
#           ...,
#           [ 0.68948066,  0.3798679 ],
#           [ 0.04078049,  0.0851227 ],
#           [ 0.15809637,  0.16280222]]], dtype=float32),
#   'denorm': array([[[ 444.57947, 1214.94   ],
#           [ 491.82092,  835.63654],
#           [ 561.2018 ,  588.8271 ],
#           ...,
#           [ 558.0858 , 3012.8767 ],
#           [ 512.0522 , 1112.4812 ],
#           [ 492.10663, 2098.7495 ]],
#
#          [[ 444.60867, 1213.9149 ],
#           [ 489.42914, 1170.319  ],
#           [ 561.2018 ,  588.8271 ],
#           ...,
#           [ 557.1358 , 3014.2974 ],
#           [ 512.0522 , 1112.4812 ],
#           [ 508.8074 , 2127.144  ]],
#
#          [[ 444.5957 , 1207.7972 ],
#           [ 491.82092,  835.63654],
#           [ 561.2018 ,  588.8271 ],
#           ...,
#           [ 558.3161 , 3008.3416 ],
#           [ 512.0522 , 1112.4812 ],
#           [ 509.78284, 2089.7925 ]],
#
#          ...,
#
#          [[ 454.11566,  984.37103],
#           [ 451.33997, 5640.327  ],
#           [ 567.4477 ,  721.351  ],
#           ...,
#           [ 585.0532 , 4127.128  ],
#           [ 517.47125,  924.7246 ],
#           [ 529.6988 , 1768.5908 ]],
#
#          [[ 454.11566,  984.37103],
#           [ 451.33997, 5640.327  ],
#           [ 567.4477 ,  721.351  ],
#           ...,
#           [ 585.0532 , 4127.128  ],
#           [ 517.47125,  924.7246 ],
#           [ 528.13074, 1774.582  ]],
#
#          [[ 469.1448 , 1387.8297 ],
#           [ 451.33997, 5640.327  ],
#           [ 567.4477 ,  721.351  ],
#           ...,
#           [ 585.0838 , 4126.669  ],
#           [ 517.47125,  924.7246 ],
#           [ 529.6988 , 1768.5908 ]]], dtype=float32)},
#  'lourd': {'norm': array([[[ 0.50572264,  6.303343  ],
#           [ 0.45389807,  7.9819493 ],
#           [ 0.4927454 ,  6.377169  ],
#           ...,
#           [ 0.37927657,  2.2592735 ],
#           [ 0.37780023,  2.454002  ],
#           [ 0.47737187,  0.37516809]],
#
#          [[ 0.50572264,  6.303343  ],
#           [ 0.45389807,  7.9819493 ],
#           [ 0.4927454 ,  6.377169  ],
#           ...,
#           [ 0.38635212,  1.6232274 ],
#           [-0.05132818,  3.7001786 ],
#           [ 0.3828858 ,  2.1501231 ]],
#
#          [[ 0.50572264,  6.303343  ],
#           [ 0.5282813 ,  6.247268  ],
#           [ 0.4927454 ,  6.377169  ],
#           ...,
#           [ 0.33357322,  2.6551557 ],
#           [ 0.38392043,  2.2929301 ],
#           [ 0.3828858 ,  2.1501231 ]],
#
#          ...,
#
#          [[ 0.6111692 ,  1.0753583 ],
#           [ 0.6529486 ,  1.0359911 ],
#           [ 0.6119114 ,  1.0828353 ],
#           ...,
#           [ 0.4767002 ,  0.5080797 ],
#           [ 0.4861384 ,  0.481683  ],
#           [ 0.48850977,  0.47392586]],
#
#          [[ 0.6111692 ,  1.0753583 ],
#           [ 0.6529486 ,  1.0359911 ],
#           [ 0.7299545 ,  0.61385715],
#           ...,
#           [ 0.4594339 ,  0.5114953 ],
#           [ 0.4861384 ,  0.481683  ],
#           [ 0.54336846,  0.46537954]],
#
#          [[ 0.44918904,  0.6189008 ],
#           [ 0.6529486 ,  1.0359911 ],
#           [ 0.6119114 ,  1.0828353 ],
#           ...,
#           [ 0.4594339 ,  0.5114953 ],
#           [ 0.5108609 ,  0.50384915],
#           [ 0.48850977,  0.47392586]]], dtype=float32),
#   'denorm': array([[[  565.9311 , 68475.94   ],
#           [  560.52954, 86711.36   ],
#           [  564.57855, 69277.94   ],
#           ...,
#           [  552.75195, 24543.463  ],
#           [  552.598  , 26658.883  ],
#           [  562.9762 ,  4075.6128 ]],
#
#          [[  565.9311 , 68475.94   ],
#           [  560.52954, 86711.36   ],
#           [  564.57855, 69277.94   ],
#           ...,
#           [  553.4894 , 17633.82   ],
#           [  507.87094, 40196.637  ],
#           [  553.1281 , 23357.715  ]],
#
#          [[  565.9311 , 68475.94   ],
#           [  568.28235, 67866.77   ],
#           [  564.57855, 69277.94   ],
#           ...,
#           [  547.98834, 28844.102  ],
#           [  553.23596, 24909.09   ],
#           [  553.1281 , 23357.715  ]],
#
#          ...,
#
#          [[  576.9216 , 11682.081  ],
#           [  581.2761 , 11254.418  ],
#           [  576.99896, 11763.308  ],
#           ...,
#           [  562.9062 ,  5519.4893 ],
#           [  563.8899 ,  5232.73   ],
#           [  564.1371 ,  5148.461  ]],
#
#          [[  576.9216 , 11682.081  ],
#           [  581.2761 , 11254.418  ],
#           [  589.3023 ,  6668.595  ],
#           ...,
#           [  561.10657,  5556.594  ],
#           [  563.8899 ,  5232.73   ],
#           [  569.85486,  5055.6187 ]],
#
#          [[  560.03876,  6723.386  ],
#           [  581.2761 , 11254.418  ],
#           [  576.99896, 11763.308  ],
#           ...,
#           [  561.10657,  5556.594  ],
#           [  566.4667 ,  5473.531  ],
#           [  564.1371 ,  5148.461  ]]], dtype=float32)}}

# %%
uncertainties, sqr_errors = compute_error(predictions, datasets, "power_smoothed")
uncertainties
# Out:
# {'val': {'tvar': array([1010.43146, 1629.3661 , 2086.7925 , ..., 1435.7616 , 1949.3267 ,
#          1292.2162 ], dtype=float32),
#   'mvar': array([ 911.404 , 1603.878 , 2057.2727, ..., 1418.5994, 1897.4458,
#          1255.7157], dtype=float32),
#   'varm': array([99.02748 , 25.488043, 29.519657, ..., 17.162199, 51.880905,
#          36.500507], dtype=float32),
#   'epkl': array([4.946594 , 5.1291275, 5.2577324, ..., 5.0648804, 5.248863 ,
#          5.020851 ], dtype=float32)},
#  'train': {'tvar': array([3917.1208, 1153.2778, 3206.1016, ..., 1563.8059,  781.9118,
#          1509.3344], dtype=float32),
#   'mvar': array([3189.256 , 1127.1154, 3119.531 , ..., 1529.2009,  766.9046,
#          1473.6578], dtype=float32),
#   'varm': array([727.8648  ,  26.162485,  86.57056 , ...,  34.604946,  15.007214,
#           35.67648 ], dtype=float32),
#   'epkl': array([5.7353897, 4.965004 , 5.47596  , ..., 5.1131744, 4.7608185,
#          5.0963745], dtype=float32)},
#  'test': {'tvar': array([1398.036  , 2922.1812 ,  691.31287, ..., 4424.761  , 1124.2905 ,
#          2164.2344 ], dtype=float32),
#   'mvar': array([1291.0176, 2495.8218,  675.8864, ..., 4159.0366, 1108.58  ,
#          2057.2947], dtype=float32),
#   'varm': array([107.018394 , 426.3594   ,  15.426431 , ..., 265.7244   ,
#           15.7106085, 106.939705 ], dtype=float32),
#   'epkl': array([5.096245 , 5.8933945, 4.702942 , ..., 5.663723 , 4.9456635,
#          5.290535 ], dtype=float32)},
#  'lourd': {'tvar': array([42798.938, 53341.227, 44564.633, ..., 15702.172, 16877.254,
#          14926.024], dtype=float32),
#   'mvar': array([42618.38 , 52903.188, 44403.41 , ..., 15572.676, 16754.455,
#          14888.235], dtype=float32),
#   'varm': array([180.55922 , 438.04022 , 161.2236  , ..., 129.49594 , 122.7979  ,
#           37.788624], dtype=float32),
#   'epkl': array([7.0320706, 7.267562 , 7.1034346, ..., 6.4486904, 6.5058384,
#          6.4059925], dtype=float32)}}

# %% [markdown]
# ## Plots
# ### MSE retention values

# %%
print(sqr_errors.keys())
sets_names = ['val', 'train', 'test']
# Out:
# dict_keys(['val', 'train', 'test', 'lourd'])

# %%
error_retention_plot_allsets(uncertainties, sqr_errors, sets_names)

# %% [markdown]
# ### F1 retention curves

# %% [markdown]
# #### Define threshold of acceptable errors

# %%
# Use an acceptable error threshold of (500 kW)^2
thresh = 20 ** 2 # moitié de rmse dans le tableau plus bas, au carré

# %% [markdown]
# #### Plot F1 retentions

# %%
f1_retention_plot_allsets (uncertainties, sqr_errors, sets_names, thresh=20000)

# %% [markdown]
# ## Predictive performance Tables

# %%
table_errors(predictions, datasets, target)
# Out:
# Classic metrics
# ╒════════╤══════════════════╤═════════════════╤═════════════╕
# │ Data   │   RMSE Ens. (KW) │   MAE Ens. (KW) │    MAPE (%) │
# ╞════════╪══════════════════╪═════════════════╪═════════════╡
# │ val    │               67 │              36 │ 65.72       │
# ├────────┼──────────────────┼─────────────────┼─────────────┤
# │ train  │               67 │              36 │  4.2894e+15 │
# ├────────┼──────────────────┼─────────────────┼─────────────┤
# │ test   │               68 │              36 │ 69.11       │
# ├────────┼──────────────────┼─────────────────┼─────────────┤
# │ lourd  │               91 │              50 │ 92.43       │
# ╘════════╧══════════════════╧═════════════════╧═════════════╛

# %%
table_auc(sets_names, sqr_errors, uncertainties, thresh)
# Out:
# AUCs
# ╒════════╤═════════╤══════════╤═════════════╕
# │ Data   │   R-AUC │   F1-AUC │   F1 @ 95 % │
# ╞════════╪═════════╪══════════╪═════════════╡
# │ val    │ 548.7   │    0.536 │       0.664 │
# ├────────┼─────────┼──────────┼─────────────┤
# │ train  │ 568.033 │    0.535 │       0.665 │
# ├────────┼─────────┼──────────┼─────────────┤
# │ test   │ 570.725 │    0.534 │       0.666 │
# ╘════════╧═════════╧══════════╧═════════════╛

# %% [markdown]
# # Plot predictions

# %%
# quel est le vol le plus utilisé dans l'entrainement ?
datasets["train"].groupby("flight")["angular_x"].count().sort_values()
# Out:
# flight
# 187     450
# 235     463
# 14      469
# 98      473
# 111     476
#        ...
# 237    1031
# 126    1038
# 184    1040
# 210    1047
# 272    1337
# Name: angular_x, Length: 195, dtype: int64

# %%
# retrouver les index des predictions + repasser à std au lieu de variance -> dans un df
pred_test = predictions["test"]["denorm"]
pred_test_moy = np.zeros([pred_test.shape[1], 2])
for i in range(pred_test.shape[1]):
    pred_test_moy[i,0] = np.mean(pred_test[:,i,0])
    pred_test_moy[i,1] = np.mean(np.sqrt(pred_test[:,i,1]))

pred_test_moy = pd.DataFrame(pred_test_moy, index=datasets["test"].index, columns=["mean", "std"])
pred_test_moy
# Out:
#               mean        std
# index
# 141203  446.921326  35.757496
# 20642   480.202118  45.257648
# 117547  565.783142  25.960794
# 183285  511.619324  29.932119
# 170778  542.760498  30.613644
# ...            ...        ...
# 7515    445.626953  33.820389
# 171028  559.895935  30.445520
# 69521   564.074097  64.068153
# 159549  513.561829  33.134323
# 225069  515.582336  45.292301
#
# [38614 rows x 2 columns]

# %%
def plot_flight_pred(datasets, flight, pred_test_moy, test_name, target):
    """ Plot one flight and its predictions given by the model, as well as real data for those points """
    figsize=(25,15)
    # plot line for data of this flight
    dataset_complete = pd.concat([datasets[k] for k in datasets.keys()])
    dataset_complete.loc[dataset_complete.flight == flight, target].sort_index().plot(marker="", figsize=figsize, label="real data")
    display(dataset_complete.loc[dataset_complete.flight == flight].sort_index())
    # plot markers of test labels
    data_test = datasets[test_name]
    ex_test = data_test.loc[data_test.flight == flight].sort_index()
    display(ex_test)
    dataset_complete.loc[ex_test.index,target].plot(marker=".", figsize=figsize, ls='', label="labels", color="r")
    # ex_test["power"].plot(marker=".", figsize=figsize, ls='', label="labels", color="r")
    data_test.loc[data_test.flight==flight, target].sort_index().plot(marker=".", figsize=figsize, ls='', label="labels", color="r")
    # plot predictions with uncertainty
    yerr = pred_test_moy.loc[ex_test.index, "std"].sort_index()
    moy = pred_test_moy.loc[ex_test.index,"mean"].sort_index()
    moy.plot(marker=".", figsize=figsize, ls='-', label="mean prediction", color="black")
    plt.fill_between(ex_test.index, moy - yerr, moy + yerr, color="black", alpha=0.2)

    # plt.xlim(250250, 250600)
    plt.legend()
    plt.grid()
    plt.show()

plot_flight_pred(datasets, 272, pred_test_moy, "test", "power_smoothed")
# Out:
#                  time_start  flight    time  wind_speed  wind_angle  \
# index
# 250142  2019-09-19 10:29:00     272    0.00         0.5       319.0
# 250143  2019-09-19 10:29:00     272    0.20         0.5       321.0
# 250144  2019-09-19 10:29:00     272    0.30         0.5       325.0
# 250145  2019-09-19 10:29:00     272    0.51         0.5       324.0
# 250146  2019-09-19 10:29:00     272    0.61         0.6       325.0
# ...                     ...     ...     ...         ...         ...
# 251988  2019-09-19 10:29:00     272  276.91         2.2       258.0
# 251989  2019-09-19 10:29:00     272  277.10         2.3       260.0
# 251990  2019-09-19 10:29:00     272  277.20         2.3       266.0
# 251991  2019-09-19 10:29:00     272  277.40         2.3       265.0
# 251992  2019-09-19 10:29:00     272  277.50         2.3       268.0
#
#         battery_voltage  battery_current  position_x  position_y  position_z  \
# index
# 250142        24.522665         0.302167  -79.782830   40.459016  266.307265
# 250143        24.361151         2.170834  -79.782830   40.459016  266.314653
# 250144        24.505136         0.333975  -79.782830   40.459016  266.321527
# 250145        23.205507        19.155823  -79.782830   40.459016  266.321690
# 250146        24.448793         1.574451  -79.782830   40.459015  266.328474
# ...                 ...              ...         ...         ...         ...
# 251988        22.287754         4.516608  -79.782845   40.459000  265.814547
# 251989        22.300276         4.651788  -79.782845   40.459000  265.802198
# 251990        22.304031         4.564318  -79.782845   40.459000  265.829081
# 251991        22.341593         3.363600  -79.782845   40.459000  265.848397
# 251992        22.516880        -0.031807  -79.782845   40.459000  265.839069
#
#         ...  angular_z  linear_acceleration_x  linear_acceleration_y  \
# index   ...
# 250142  ...  -0.002794               0.574107              -0.132004
# 250143  ...  -0.006558               0.583756              -0.126945
# 250144  ...   0.012839               0.591600              -0.095437
# 250145  ...  -0.007773               0.595155              -0.124009
# 250146  ...  -0.007116               0.539788              -0.179882
# ...     ...        ...                    ...                    ...
# 251988  ...   0.009623               0.308097              -0.109221
# 251989  ...  -0.086934               0.229311              -0.132198
# 251990  ...   0.040295               0.252551              -0.104589
# 251991  ...  -0.031094               0.231540              -0.170453
# 251992  ...  -0.038425               0.171203              -0.059912
#
#         linear_acceleration_z  speed  payload  altitude  route       power  \
# index
# 250142              -9.794481      4      250        50     R6    7.409950
# 250143              -9.801146      4      250        50     R6   52.884022
# 250144              -9.797760      4      250        50     R6    8.184091
# 250145              -9.814390      4      250        50     R6  444.520584
# 250146              -9.803894      4      250        50     R6   38.493432
# ...                       ...    ...      ...       ...    ...         ...
# 251988              -9.826339      4      250        50     R6  100.665043
# 251989              -9.766861      4      250        50     R6  103.736150
# 251990              -9.794949      4      250        50     R6  101.802696
# 251991              -9.782550      4      250        50     R6   75.148187
# 251992              -9.777388      4      250        50     R6   -0.716197
#
#         power_smoothed
# index
# 250142        7.409950
# 250143       52.884022
# 250144        8.184091
# 250145      444.520584
# 250146       38.493432
# ...                ...
# 251988      100.665043
# 251989      103.736150
# 251990      101.802696
# 251991       75.148187
# 251992       -0.716197
#
# [1851 rows x 29 columns]
#                  time_start  flight    time  wind_speed  wind_angle  \
# index
# 250148  2019-09-19 10:29:00     272    0.90         0.8       329.0
# 250150  2019-09-19 10:29:00     272    1.20         0.9       325.0
# 250153  2019-09-19 10:29:00     272    1.70         1.0       321.0
# 250154  2019-09-19 10:29:00     272    1.81         1.0       320.0
# 250155  2019-09-19 10:29:00     272    2.00         1.0       316.0
# ...                     ...     ...     ...         ...         ...
# 251974  2019-09-19 10:29:00     272  274.80         2.8       233.0
# 251975  2019-09-19 10:29:00     272  275.00         2.7       238.0
# 251982  2019-09-19 10:29:00     272  276.00         2.7       246.0
# 251990  2019-09-19 10:29:00     272  277.20         2.3       266.0
# 251992  2019-09-19 10:29:00     272  277.50         2.3       268.0
#
#         battery_voltage  battery_current  position_x  position_y  position_z  \
# index
# 250148        24.523918         1.383609  -79.782830   40.459015  266.333118
# 250150        24.273506         5.057328  -79.782830   40.459015  266.338264
# 250153        23.890379        11.649349  -79.782830   40.459015  266.345057
# 250154        23.792719        13.176089  -79.782830   40.459015  266.348017
# 250155        23.591139        16.738483  -79.782830   40.459015  266.348865
# ...                 ...              ...         ...         ...         ...
# 251974        21.766901        15.410538  -79.782845   40.458999  265.989550
# 251975        21.804462        14.321145  -79.782845   40.458999  265.920706
# 251982        22.382910         2.170834  -79.782845   40.458999  265.810252
# 251990        22.304031         4.564318  -79.782845   40.459000  265.829081
# 251992        22.516880        -0.031807  -79.782845   40.459000  265.839069
#
#         ...  angular_z  linear_acceleration_x  linear_acceleration_y  \
# index   ...
# 250148  ...   0.006830               0.555986              -0.121363
# 250150  ...  -0.001066               0.572722              -0.140163
# 250153  ...  -0.042580               0.653410              -0.271956
# 250154  ...   0.066030               0.623719              -0.158093
# 250155  ...   0.041715               0.568773              -0.218040
# ...     ...        ...                    ...                    ...
# 251974  ...  -0.045751              -0.070699               0.013964
# 251975  ...   0.206530              -0.415217               0.850569
# 251982  ...   0.017868               0.224247              -0.126995
# 251990  ...   0.040295               0.252551              -0.104589
# 251992  ...  -0.038425               0.171203              -0.059912
#
#         linear_acceleration_z  speed  payload  altitude  route       power  \
# index
# 250148              -9.791325      4      250        50     R6   33.931506
# 250150              -9.806115      4      250        50     R6  122.759088
# 250153              -9.820437      4      250        50     R6  278.307367
# 250154              -9.847524      4      250        50     R6  313.494988
# 250155              -9.837639      4      250        50     R6  394.879887
# ...                       ...    ...      ...       ...    ...         ...
# 251974              -9.365030      4      250        50     R6  335.439649
# 251975             -10.121136      4      250        50     R6  312.264869
# 251982              -9.829260      4      250        50     R6   48.589588
# 251990              -9.794949      4      250        50     R6  101.802696
# 251992              -9.777388      4      250        50     R6   -0.716197
#
#         power_smoothed
# index
# 250148       33.931506
# 250150      122.759088
# 250153      289.819690
# 250154      334.113624
# 250155      373.209683
# ...                ...
# 251974      359.948029
# 251975      326.200891
# 251982       50.909112
# 251990      101.802696
# 251992       -0.716197
#
# [391 rows x 29 columns]

# %%
plot_flight_pred(datasets, 272, pred_test_moy, "test", "power_smoothed")
# Out:
#                  time_start  flight    time  wind_speed  wind_angle  \
# index
# 250142  2019-09-19 10:29:00     272    0.00         0.5       319.0
# 250143  2019-09-19 10:29:00     272    0.20         0.5       321.0
# 250144  2019-09-19 10:29:00     272    0.30         0.5       325.0
# 250145  2019-09-19 10:29:00     272    0.51         0.5       324.0
# 250146  2019-09-19 10:29:00     272    0.61         0.6       325.0
# ...                     ...     ...     ...         ...         ...
# 251988  2019-09-19 10:29:00     272  276.91         2.2       258.0
# 251989  2019-09-19 10:29:00     272  277.10         2.3       260.0
# 251990  2019-09-19 10:29:00     272  277.20         2.3       266.0
# 251991  2019-09-19 10:29:00     272  277.40         2.3       265.0
# 251992  2019-09-19 10:29:00     272  277.50         2.3       268.0
#
#         battery_voltage  battery_current  position_x  position_y  position_z  \
# index
# 250142        24.522665         0.302167  -79.782830   40.459016  266.307265
# 250143        24.361151         2.170834  -79.782830   40.459016  266.314653
# 250144        24.505136         0.333975  -79.782830   40.459016  266.321527
# 250145        23.205507        19.155823  -79.782830   40.459016  266.321690
# 250146        24.448793         1.574451  -79.782830   40.459015  266.328474
# ...                 ...              ...         ...         ...         ...
# 251988        22.287754         4.516608  -79.782845   40.459000  265.814547
# 251989        22.300276         4.651788  -79.782845   40.459000  265.802198
# 251990        22.304031         4.564318  -79.782845   40.459000  265.829081
# 251991        22.341593         3.363600  -79.782845   40.459000  265.848397
# 251992        22.516880        -0.031807  -79.782845   40.459000  265.839069
#
#         ...  angular_z  linear_acceleration_x  linear_acceleration_y  \
# index   ...
# 250142  ...  -0.002794               0.574107              -0.132004
# 250143  ...  -0.006558               0.583756              -0.126945
# 250144  ...   0.012839               0.591600              -0.095437
# 250145  ...  -0.007773               0.595155              -0.124009
# 250146  ...  -0.007116               0.539788              -0.179882
# ...     ...        ...                    ...                    ...
# 251988  ...   0.009623               0.308097              -0.109221
# 251989  ...  -0.086934               0.229311              -0.132198
# 251990  ...   0.040295               0.252551              -0.104589
# 251991  ...  -0.031094               0.231540              -0.170453
# 251992  ...  -0.038425               0.171203              -0.059912
#
#         linear_acceleration_z  speed  payload  altitude  route       power  \
# index
# 250142              -9.794481      4      250        50     R6    7.409950
# 250143              -9.801146      4      250        50     R6   52.884022
# 250144              -9.797760      4      250        50     R6    8.184091
# 250145              -9.814390      4      250        50     R6  444.520584
# 250146              -9.803894      4      250        50     R6   38.493432
# ...                       ...    ...      ...       ...    ...         ...
# 251988              -9.826339      4      250        50     R6  100.665043
# 251989              -9.766861      4      250        50     R6  103.736150
# 251990              -9.794949      4      250        50     R6  101.802696
# 251991              -9.782550      4      250        50     R6   75.148187
# 251992              -9.777388      4      250        50     R6   -0.716197
#
#         power_smoothed
# index
# 250142        7.409950
# 250143       52.884022
# 250144        8.184091
# 250145      444.520584
# 250146       38.493432
# ...                ...
# 251988      100.665043
# 251989      103.736150
# 251990      101.802696
# 251991       75.148187
# 251992       -0.716197
#
# [1851 rows x 29 columns]
#                  time_start  flight    time  wind_speed  wind_angle  \
# index
# 250148  2019-09-19 10:29:00     272    0.90         0.8       329.0
# 250150  2019-09-19 10:29:00     272    1.20         0.9       325.0
# 250153  2019-09-19 10:29:00     272    1.70         1.0       321.0
# 250154  2019-09-19 10:29:00     272    1.81         1.0       320.0
# 250155  2019-09-19 10:29:00     272    2.00         1.0       316.0
# ...                     ...     ...     ...         ...         ...
# 251974  2019-09-19 10:29:00     272  274.80         2.8       233.0
# 251975  2019-09-19 10:29:00     272  275.00         2.7       238.0
# 251982  2019-09-19 10:29:00     272  276.00         2.7       246.0
# 251990  2019-09-19 10:29:00     272  277.20         2.3       266.0
# 251992  2019-09-19 10:29:00     272  277.50         2.3       268.0
#
#         battery_voltage  battery_current  position_x  position_y  position_z  \
# index
# 250148        24.523918         1.383609  -79.782830   40.459015  266.333118
# 250150        24.273506         5.057328  -79.782830   40.459015  266.338264
# 250153        23.890379        11.649349  -79.782830   40.459015  266.345057
# 250154        23.792719        13.176089  -79.782830   40.459015  266.348017
# 250155        23.591139        16.738483  -79.782830   40.459015  266.348865
# ...                 ...              ...         ...         ...         ...
# 251974        21.766901        15.410538  -79.782845   40.458999  265.989550
# 251975        21.804462        14.321145  -79.782845   40.458999  265.920706
# 251982        22.382910         2.170834  -79.782845   40.458999  265.810252
# 251990        22.304031         4.564318  -79.782845   40.459000  265.829081
# 251992        22.516880        -0.031807  -79.782845   40.459000  265.839069
#
#         ...  angular_z  linear_acceleration_x  linear_acceleration_y  \
# index   ...
# 250148  ...   0.006830               0.555986              -0.121363
# 250150  ...  -0.001066               0.572722              -0.140163
# 250153  ...  -0.042580               0.653410              -0.271956
# 250154  ...   0.066030               0.623719              -0.158093
# 250155  ...   0.041715               0.568773              -0.218040
# ...     ...        ...                    ...                    ...
# 251974  ...  -0.045751              -0.070699               0.013964
# 251975  ...   0.206530              -0.415217               0.850569
# 251982  ...   0.017868               0.224247              -0.126995
# 251990  ...   0.040295               0.252551              -0.104589
# 251992  ...  -0.038425               0.171203              -0.059912
#
#         linear_acceleration_z  speed  payload  altitude  route       power  \
# index
# 250148              -9.791325      4      250        50     R6   33.931506
# 250150              -9.806115      4      250        50     R6  122.759088
# 250153              -9.820437      4      250        50     R6  278.307367
# 250154              -9.847524      4      250        50     R6  313.494988
# 250155              -9.837639      4      250        50     R6  394.879887
# ...                       ...    ...      ...       ...    ...         ...
# 251974              -9.365030      4      250        50     R6  335.439649
# 251975             -10.121136      4      250        50     R6  312.264869
# 251982              -9.829260      4      250        50     R6   48.589588
# 251990              -9.794949      4      250        50     R6  101.802696
# 251992              -9.777388      4      250        50     R6   -0.716197
#
#         power_smoothed
# index
# 250148       33.931506
# 250150      122.759088
# 250153      289.819690
# 250154      334.113624
# 250155      373.209683
# ...                ...
# 251974      359.948029
# 251975      326.200891
# 251982       50.909112
# 251990      101.802696
# 251992       -0.716197
#
# [391 rows x 29 columns]
